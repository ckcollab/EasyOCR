# %%
import os
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Raynor\\src\\EasyOCR\\trainer'

# %%
opt = get_config("config_files/en_filtered_config.yaml")
train(opt, amp=False)
# Out:
# --------------------------------------------------------------------------------
# dataset_root: all_data/en_train_filtered
# opt.select_data: ['en_train_filtered']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    all_data/en_train_filtered	 dataset: en_train_filtered
# all_data/en_train_filtered/
# sub-directory:	/.	 num samples: 160000
# num total samples of en_train_filtered: 160000 x 1.0 (total_data_usage_ratio) = 160000
# num samples of en_train_filtered per batch: 32 x 1.0 (batch_ratio) = 32
# --------------------------------------------------------------------------------
# Total_batch_size: 32 = 32
# --------------------------------------------------------------------------------
# dataset_root:    all_data/en_val	 dataset: /
# all_data/en_val/
# sub-directory:	/.	 num samples: 33600
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 64 600 20 1 256 256 96 34 None VGG BiLSTM CTC
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=96, bias=True)
#   )
# )
# Modules, Parameters
# module.FeatureExtraction.ConvNet.0.weight 288
# module.FeatureExtraction.ConvNet.0.bias 32
# module.FeatureExtraction.ConvNet.3.weight 18432
# module.FeatureExtraction.ConvNet.3.bias 64
# module.FeatureExtraction.ConvNet.6.weight 73728
# module.FeatureExtraction.ConvNet.6.bias 128
# module.FeatureExtraction.ConvNet.8.weight 147456
# module.FeatureExtraction.ConvNet.8.bias 128
# module.FeatureExtraction.ConvNet.11.weight 294912
# module.FeatureExtraction.ConvNet.12.weight 256
# module.FeatureExtraction.ConvNet.12.bias 256
# module.FeatureExtraction.ConvNet.14.weight 589824
# module.FeatureExtraction.ConvNet.15.weight 256
# module.FeatureExtraction.ConvNet.15.bias 256
# module.FeatureExtraction.ConvNet.18.weight 262144
# module.FeatureExtraction.ConvNet.18.bias 256
# module.SequenceModeling.0.rnn.weight_ih_l0 262144
# module.SequenceModeling.0.rnn.weight_hh_l0 262144
# module.SequenceModeling.0.rnn.bias_ih_l0 1024
# module.SequenceModeling.0.rnn.bias_hh_l0 1024
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.0.linear.weight 131072
# module.SequenceModeling.0.linear.bias 256
# module.SequenceModeling.1.rnn.weight_ih_l0 262144
# module.SequenceModeling.1.rnn.weight_hh_l0 262144
# module.SequenceModeling.1.rnn.bias_ih_l0 1024
# module.SequenceModeling.1.rnn.bias_hh_l0 1024
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.1.linear.weight 131072
# module.SequenceModeling.1.linear.bias 256
# module.Prediction.weight 24576
# module.Prediction.bias 96
# Total Trainable Params: 3781088
# Trainable params num :  3781088
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1.0
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number: 0123456789
# symbol: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# lang_char: ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# experiment_name: en_filtered
# train_data: all_data/en_train_filtered
# valid_data: all_data/en_val
# manualSeed: 1111
# workers: 4
# batch_size: 32
# num_iter: 300000
# valInterval: 10000
# saved_model:
# FT: False
# optim: False
# lr: 1.0
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['en_train_filtered']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 34
# imgH: 64
# imgW: 600
# rgb: False
# sensitive: True
# PAD: True
# contrast_adjust: 0.0
# data_filtering_off: True
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 256
# hidden_size: 256
# decode: greedy
# new_prediction: True
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character: 0123456789!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# num_class: 96
# ---------------------------------------
#
# Finished epoch 1000
# Finished epoch 2000
# Finished epoch 3000
# Finished epoch 4000
# Finished epoch 5000
# Finished epoch 6000
# Finished epoch 7000
# Finished epoch 8000
# Finished epoch 9000
# training time:  1180.244975566864
# [10000/300000] Train loss: 0.20615, Valid loss: 0.01777, Elapsed_time: 1180.24599
# Current_accuracy : 94.330, Current_norm_ED  : 0.9946
# Best_accuracy    : 94.330, Best_norm_ED     : 0.9946
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# +702% Enhanced Damage     | +702% Enhanced Damage     | 0.0888	True
# Orphan's Call             | Orphan's Call             | 0.3998	True
# --------------------------------------------------------------------------------
# validation time:  601.5031640529633
# Finished epoch 10000
# Finished epoch 11000
# Finished epoch 12000
# Finished epoch 13000
# Finished epoch 14000
# Finished epoch 15000
# Finished epoch 16000
# Finished epoch 17000
# Finished epoch 18000
# Finished epoch 19000
# training time:  1155.7974467277527
# [20000/300000] Train loss: 0.01174, Valid loss: 0.00860, Elapsed_time: 2937.54660
# Current_accuracy : 97.321, Current_norm_ED  : 0.9973
# Best_accuracy    : 97.321, Best_norm_ED     : 0.9973
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 'RalOhmSurEth'            | 'RalOhmSurEth'            | 0.6327	True
# Bonesaw Breaker           | Bonesaw Breaker           | 0.2326	True
# --------------------------------------------------------------------------------
# validation time:  581.7095715999603
# Finished epoch 20000
# Finished epoch 21000
# Finished epoch 22000
# Finished epoch 23000
# Finished epoch 24000
# Finished epoch 25000
# Finished epoch 26000
# Finished epoch 27000
# Finished epoch 28000
# Finished epoch 29000
# training time:  1153.7866551876068
# [30000/300000] Train loss: 0.00735, Valid loss: 0.00681, Elapsed_time: 4673.04282
# Current_accuracy : 97.958, Current_norm_ED  : 0.9974
# Best_accuracy    : 97.958, Best_norm_ED     : 0.9974
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# +740% Enhanced Defense    | +740% Enhanced Defense    | 0.2025	True
# Defense: 652              | Defense: 652              | 0.4430	True
# --------------------------------------------------------------------------------
# validation time:  580.0565118789673
# Finished epoch 30000
# Finished epoch 31000
# Finished epoch 32000
# Finished epoch 33000
# Finished epoch 34000
# Finished epoch 35000
# Finished epoch 36000
# Finished epoch 37000
# Finished epoch 38000
# Finished epoch 39000
# training time:  1153.618593454361
# [40000/300000] Train loss: 0.00575, Valid loss: 0.00818, Elapsed_time: 6406.71793
# Current_accuracy : 97.583, Current_norm_ED  : 0.9968
# Best_accuracy    : 97.958, Best_norm_ED     : 0.9974
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Required Level: 76        | Required Level: 76        | 0.4626	True
# Carapace                  | Carapace                  | 0.6128	True
# --------------------------------------------------------------------------------
# validation time:  583.2767646312714
# Finished epoch 40000
# Finished epoch 41000
# Finished epoch 42000
# Finished epoch 43000
# Finished epoch 44000
# Finished epoch 45000
# Finished epoch 46000
# Finished epoch 47000
# Finished epoch 48000
# Finished epoch 49000
# training time:  1204.262809753418
# [50000/300000] Train loss: 0.00495, Valid loss: 0.00504, Elapsed_time: 8194.25750
# Current_accuracy : 98.435, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.435, Best_norm_ED     : 0.9980
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Defense: 697              | Defense: 697              | 0.4728	True
# +455% Enhanced Damage     | +455% Enhanced Damage     | 0.0258	True
# --------------------------------------------------------------------------------
# validation time:  642.4642236232758
# Finished epoch 50000
# Finished epoch 51000
# Finished epoch 52000
# Finished epoch 53000
# Finished epoch 54000
# Finished epoch 55000
# Finished epoch 56000
# Finished epoch 57000
# Finished epoch 58000
# Finished epoch 59000
# training time:  1205.3776712417603
# [60000/300000] Train loss: 0.00439, Valid loss: 0.00573, Elapsed_time: 10042.10040
# Current_accuracy : 98.324, Current_norm_ED  : 0.9979
# Best_accuracy    : 98.435, Best_norm_ED     : 0.9980
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Use Belt 4                | Use Belt 4                | 0.8904	True
# +630% Enhanced Defense    | +630% Enhanced Defense    | 0.3854	True
# --------------------------------------------------------------------------------
# validation time:  639.883781671524
# Finished epoch 60000
# Finished epoch 61000
# Finished epoch 62000
# Finished epoch 63000
# Finished epoch 64000
# Finished epoch 65000
# Finished epoch 66000
# Finished epoch 67000
# Finished epoch 68000
# Finished epoch 69000
# training time:  1204.2334229946136
# [70000/300000] Train loss: 0.00411, Valid loss: 0.00542, Elapsed_time: 11886.21760
# Current_accuracy : 98.560, Current_norm_ED  : 0.9979
# Best_accuracy    : 98.560, Best_norm_ED     : 0.9980
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# The Moldy Tome            | The Moldy Tome            | 0.3558	True
# wrist sword               | Wrist sword               | 0.1650	False
# --------------------------------------------------------------------------------
# validation time:  585.2807970046997
# Finished epoch 70000
# Finished epoch 71000
# Finished epoch 72000
# Finished epoch 73000
# Finished epoch 74000
# Finished epoch 75000
# Finished epoch 76000
# Finished epoch 77000
# Finished epoch 78000
# Finished epoch 79000
# training time:  1184.9409050941467
# [80000/300000] Train loss: 0.00404, Valid loss: 0.00449, Elapsed_time: 13656.43930
# Current_accuracy : 98.735, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9980
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Wight                     | Wight                     | 0.7229	True
# creates a barrier of bone around target | creates a barrier of bone around target | 0.2651	True
# --------------------------------------------------------------------------------
# validation time:  820.3728322982788
# Finished epoch 80000
# Finished epoch 81000
# Finished epoch 82000
# Finished epoch 83000
# Finished epoch 84000
# Finished epoch 85000
# Finished epoch 86000
# Finished epoch 87000
# Finished epoch 88000
# Finished epoch 89000
# training time:  1196.6901051998138
# [90000/300000] Train loss: 0.00368, Valid loss: 0.00538, Elapsed_time: 15673.50224
# Current_accuracy : 98.589, Current_norm_ED  : 0.9977
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9980
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# +822% Enhanced Defense    | +822% Enhanced Defense    | 0.3583	True
# 68% Mana stolen per hit   | 68% Mana stolen per hit   | 0.6966	True
# --------------------------------------------------------------------------------
# validation time:  583.2649583816528
# Finished epoch 90000
# Finished epoch 91000
# Finished epoch 92000
# Finished epoch 93000
# Finished epoch 94000
# Finished epoch 95000
# Finished epoch 96000
# Finished epoch 97000
# Finished epoch 98000
# Finished epoch 99000
# training time:  1154.480679512024
# [100000/300000] Train loss: 0.00353, Valid loss: 0.00479, Elapsed_time: 17411.24788
# Current_accuracy : 98.509, Current_norm_ED  : 0.9979
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9980
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Asheara                   | Asheara                   | 0.2912	True
# Class Specific            | Class Specific            | 0.8723	True
# --------------------------------------------------------------------------------
# validation time:  586.5478024482727
# Finished epoch 100000
# Finished epoch 101000
# Finished epoch 102000
# Finished epoch 103000
# Finished epoch 104000
# Finished epoch 105000
# Finished epoch 106000
# Finished epoch 107000
# Finished epoch 108000
# Finished epoch 109000
# training time:  1154.6228494644165
# [110000/300000] Train loss: 0.00341, Valid loss: 0.00552, Elapsed_time: 19152.41853
# Current_accuracy : 98.542, Current_norm_ED  : 0.9976
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9980
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# amulet                    | Amulet                    | 0.3423	False
# Knout                     | Knout                     | 0.7716	True
# --------------------------------------------------------------------------------
# validation time:  591.9499485492706
# Finished epoch 110000
# Finished epoch 111000
# Finished epoch 112000
# Finished epoch 113000
# Finished epoch 114000
# Finished epoch 115000
# Finished epoch 116000
# Finished epoch 117000
# Finished epoch 118000
# Finished epoch 119000
# training time:  1267.8236236572266
# [120000/300000] Train loss: 0.00329, Valid loss: 0.00462, Elapsed_time: 21012.19310
# Current_accuracy : 98.604, Current_norm_ED  : 0.9982
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# creates a freezing ring   | creates a freezing ring   | 0.2995	True
# Defense: 748              | Defense: 748              | 0.4914	True
# --------------------------------------------------------------------------------
# validation time:  748.1835021972656
# Finished epoch 120000
# Finished epoch 121000
# Finished epoch 122000
# Finished epoch 123000
# Finished epoch 124000
# Finished epoch 125000
# Finished epoch 126000
# Finished epoch 127000
# Finished epoch 128000
# Finished epoch 129000
# training time:  1206.207453250885
# [130000/300000] Train loss: 0.00319, Valid loss: 0.00497, Elapsed_time: 22966.58406
# Current_accuracy : 98.640, Current_norm_ED  : 0.9981
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# +798% Enhanced Damage     | +798% Enhanced Damage     | 0.1826	True
# +367% Enhanced Damage     | +367% Enhanced Damage     | 0.1214	True
# --------------------------------------------------------------------------------
# validation time:  692.3758113384247
# Finished epoch 130000
# Finished epoch 131000
# Finished epoch 132000
# Finished epoch 133000
# Finished epoch 134000
# Finished epoch 135000
# Finished epoch 136000
# Finished epoch 137000
# Finished epoch 138000
# Finished epoch 139000
# training time:  1185.3955488204956
# [140000/300000] Train loss: 0.00300, Valid loss: 0.00587, Elapsed_time: 24844.35542
# Current_accuracy : 98.405, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Flawless Skull            | Flawless Skull            | 0.6294	True
# +203% Enhanced Defense    | +203% Enhanced Defense    | 0.3060	True
# --------------------------------------------------------------------------------
# validation time:  586.0208501815796
# Finished epoch 140000
# Finished epoch 141000
# Finished epoch 142000
# Finished epoch 143000
# Finished epoch 144000
# Finished epoch 145000
# Finished epoch 146000
# Finished epoch 147000
# Finished epoch 148000
# Finished epoch 149000
# training time:  1153.584229707718
# [150000/300000] Train loss: 0.00294, Valid loss: 0.00510, Elapsed_time: 26583.96050
# Current_accuracy : 98.539, Current_norm_ED  : 0.9981
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Oak Sage                  | Oak Sage                  | 0.6727	True
# Sword Mastery             | Sword Mastery             | 0.2020	True
# --------------------------------------------------------------------------------
# validation time:  585.6899344921112
# Finished epoch 150000
# Finished epoch 151000
# Finished epoch 152000
# Finished epoch 153000
# Finished epoch 154000
# Finished epoch 155000
# Finished epoch 156000
# Finished epoch 157000
# Finished epoch 158000
# Finished epoch 159000
# training time:  1154.0621237754822
# [160000/300000] Train loss: 0.00263, Valid loss: 0.00664, Elapsed_time: 28323.71256
# Current_accuracy : 98.473, Current_norm_ED  : 0.9977
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Giant Skull               | Giant Skull               | 0.4702	True
# Horror Archer             | Horror Archer             | 0.5997	True
# --------------------------------------------------------------------------------
# validation time:  577.5171182155609
# Finished epoch 160000
# Finished epoch 161000
# Finished epoch 162000
# Finished epoch 163000
# Finished epoch 164000
# Finished epoch 165000
# Finished epoch 166000
# Finished epoch 167000
# Finished epoch 168000
# Finished epoch 169000
# training time:  1154.2272682189941
# [170000/300000] Train loss: 0.00239, Valid loss: 0.00562, Elapsed_time: 30055.45694
# Current_accuracy : 98.446, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# +319% Enhanced Damage     | +319% Enhanced Damage     | 0.3803	True
# All Resistances +123}     | All Resistances +123}     | 0.4395	True
# --------------------------------------------------------------------------------
# validation time:  586.4025831222534
# Finished epoch 170000
# Finished epoch 171000
# Finished epoch 172000
# Finished epoch 173000
# Finished epoch 174000
# Finished epoch 175000
# Finished epoch 176000
# Finished epoch 177000
# Finished epoch 178000
# Finished epoch 179000
# training time:  1154.1186258792877
# [180000/300000] Train loss: 0.00225, Valid loss: 0.00720, Elapsed_time: 31795.97919
# Current_accuracy : 98.363, Current_norm_ED  : 0.9978
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Lightning Spell           | Lightning Spell           | 0.7023	True
# Battle Gauntlets          | Battle Gauntlets          | 0.2143	True
# --------------------------------------------------------------------------------
# validation time:  573.1211404800415
# Finished epoch 180000
# Finished epoch 181000
# Finished epoch 182000
# Finished epoch 183000
# Finished epoch 184000
# Finished epoch 185000
# Finished epoch 186000
# Finished epoch 187000
# Finished epoch 188000
# Finished epoch 189000
# training time:  1154.1998801231384
# [190000/300000] Train loss: 0.00201, Valid loss: 0.00583, Elapsed_time: 33523.30021
# Current_accuracy : 98.518, Current_norm_ED  : 0.9979
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Gargantuan Beast          | Gargantuan Beast          | 0.2684	True
# +733% Enhanced Damage     | +733% Enhanced Damage     | 0.1241	True
# --------------------------------------------------------------------------------
# validation time:  591.4995012283325
# Finished epoch 190000
# Finished epoch 191000
# Finished epoch 192000
# Finished epoch 193000
# Finished epoch 194000
# Finished epoch 195000
# Finished epoch 196000
# Finished epoch 197000
# Finished epoch 198000
# Finished epoch 199000
# training time:  1154.3726615905762
# [200000/300000] Train loss: 0.00185, Valid loss: 0.00630, Elapsed_time: 35269.17237
# Current_accuracy : 98.530, Current_norm_ED  : 0.9979
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Frost Nova                | Frost Nova                | 0.9723	True
# to Attack Rating against Undead | to Attack Rating against Undead | 0.2667	True
# --------------------------------------------------------------------------------
# validation time:  584.4431924819946
# Finished epoch 200000
# Finished epoch 201000
# Finished epoch 202000
# Finished epoch 203000
# Finished epoch 204000
# Finished epoch 205000
# Finished epoch 206000
# Finished epoch 207000
# Finished epoch 208000
# Finished epoch 209000
# training time:  1154.1963818073273
# [210000/300000] Train loss: 0.00160, Valid loss: 0.00660, Elapsed_time: 37007.81291
# Current_accuracy : 98.545, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Defense: 505              | Defense: 505              | 0.3788	True
# Mighty Scepter            | mighty scepter            | 0.4632	False
# --------------------------------------------------------------------------------
# validation time:  591.9822089672089
# Finished epoch 210000
# Finished epoch 211000
# Finished epoch 212000
# Finished epoch 213000
# Finished epoch 214000
# Finished epoch 215000
# Finished epoch 216000
# Finished epoch 217000
# Finished epoch 218000
# Finished epoch 219000
# training time:  1156.2648644447327
# [220000/300000] Train loss: 0.00144, Valid loss: 0.00811, Elapsed_time: 38756.05998
# Current_accuracy : 98.458, Current_norm_ED  : 0.9978
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Defense: 472              | Defense: 472              | 0.1785	True
# Forgotten Reliquary       | Forgotten Reliquary       | 0.2070	True
# --------------------------------------------------------------------------------
# validation time:  578.9482343196869
# Finished epoch 220000
# Finished epoch 221000
# Finished epoch 222000
# Finished epoch 223000
# Finished epoch 224000
# Finished epoch 225000
# Finished epoch 226000
# Finished epoch 227000
# Finished epoch 228000
# Finished epoch 229000
# training time:  1157.7959699630737
# [230000/300000] Train loss: 0.00115, Valid loss: 0.00665, Elapsed_time: 40492.80419
# Current_accuracy : 98.470, Current_norm_ED  : 0.9979
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# +179% Enhanced Defense    | +179% Enhanced Defense    | 0.3979	True
# Defense: 535              | Defense: 535              | 0.1946	True
# --------------------------------------------------------------------------------
# validation time:  577.1469914913177
# Finished epoch 230000
# Finished epoch 231000
# Finished epoch 232000
# Finished epoch 233000
# Finished epoch 234000
# Finished epoch 235000
# Finished epoch 236000
# Finished epoch 237000
# Finished epoch 238000
# Finished epoch 239000
# training time:  1157.5984854698181
# [240000/300000] Train loss: 0.00105, Valid loss: 0.00961, Elapsed_time: 42227.55066
# Current_accuracy : 98.548, Current_norm_ED  : 0.9978
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Duration reduced by       | Duration reduced by       | 0.4044	True
# +523% Enhanced Defense    | +523% Enhanced Defense    | 0.1257	True
# --------------------------------------------------------------------------------
# validation time:  588.1709539890289
# Finished epoch 240000
# Finished epoch 241000
# Finished epoch 242000
# Finished epoch 243000
# Finished epoch 244000
# Finished epoch 245000
# Finished epoch 246000
# Finished epoch 247000
# Finished epoch 248000
# Finished epoch 249000
# training time:  1157.4983487129211
# [250000/300000] Train loss: 0.00081, Valid loss: 0.00713, Elapsed_time: 43973.21997
# Current_accuracy : 98.443, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Left Hand Swing           | Left Hand Swing           | 0.4515	True
# +824% Enhanced Damage     | +824% Enhanced Damage     | 0.1732	True
# --------------------------------------------------------------------------------
# validation time:  590.32293176651
# Finished epoch 250000
# Finished epoch 251000
# Finished epoch 252000
# Finished epoch 253000
# Finished epoch 254000
# Finished epoch 255000
# Finished epoch 256000
# Finished epoch 257000
# Finished epoch 258000
# Finished epoch 259000
# training time:  1157.1060528755188
# [260000/300000] Train loss: 0.00060, Valid loss: 0.00835, Elapsed_time: 45720.64895
# Current_accuracy : 98.515, Current_norm_ED  : 0.9979
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Required Level: 17        | Required Level: 17        | 0.4636	True
# Bone Archer               | Bone Archer               | 0.5513	True
# --------------------------------------------------------------------------------
# validation time:  575.5674047470093
# Finished epoch 260000
# Finished epoch 261000
# Finished epoch 262000
# Finished epoch 263000
# Finished epoch 264000
# Finished epoch 265000
# Finished epoch 266000
# Finished epoch 267000
# Finished epoch 268000
# Finished epoch 269000
# training time:  1154.8120210170746
# [270000/300000] Train loss: 0.00045, Valid loss: 0.00959, Elapsed_time: 47451.02938
# Current_accuracy : 98.619, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Wirt's body               | Wirt's body               | 0.4781	True
# Gladius                   | Gladius                   | 0.9986	True
# --------------------------------------------------------------------------------
# validation time:  589.154422044754
# Finished epoch 270000
# Finished epoch 271000
# Finished epoch 272000
# Finished epoch 273000
# Finished epoch 274000
# Finished epoch 275000
# Finished epoch 276000
# Finished epoch 277000
# Finished epoch 278000
# Finished epoch 279000
# training time:  1154.6317174434662
# [280000/300000] Train loss: 0.00019, Valid loss: 0.00884, Elapsed_time: 49194.81552
# Current_accuracy : 98.652, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Barbed Shield             | Barbed Shield             | 0.1028	True
# Stygian Pike              | Stygian Pike              | 0.4104	True
# --------------------------------------------------------------------------------
# validation time:  591.0441648960114
# Finished epoch 280000
# Finished epoch 281000
# Finished epoch 282000
# Finished epoch 283000
# Finished epoch 284000
# Finished epoch 285000
# Finished epoch 286000
# Finished epoch 287000
# Finished epoch 288000
# Finished epoch 289000
# training time:  1157.6419522762299
# [290000/300000] Train loss: 0.00006, Valid loss: 0.00890, Elapsed_time: 50943.50163
# Current_accuracy : 98.714, Current_norm_ED  : 0.9981
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 80% Mana stolen per hit   | 80% Mana stolen per hit   | 0.2130	True
# Flesh Archer              | Flesh Archer              | 0.4166	True
# --------------------------------------------------------------------------------
# validation time:  587.8910934925079
# Finished epoch 290000
# Finished epoch 291000
# Finished epoch 292000
# Finished epoch 293000
# Finished epoch 294000
# Finished epoch 295000
# Finished epoch 296000
# Finished epoch 297000
# Finished epoch 298000
# Finished epoch 299000
# training time:  1157.7197017669678
# [300000/300000] Train loss: 0.00003, Valid loss: 0.00950, Elapsed_time: 52689.11243
# Current_accuracy : 98.673, Current_norm_ED  : 0.9980
# Best_accuracy    : 98.735, Best_norm_ED     : 0.9982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Sorceress Item            | Sorceress Item            | 0.2969	True
# Magma Torquer             | Magma Torquer             | 0.2846	True
# --------------------------------------------------------------------------------
# validation time:  588.0068101882935
# end the training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Raynor\anaconda3\envs\torch\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
